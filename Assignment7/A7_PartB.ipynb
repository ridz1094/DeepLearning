# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Create RNN Simple Model

# %%
batch_size = 64
input_dim = 28
units = 64
output_size = 10  # labels are from 0 to 9

# Build the RNN model
def build_model():
    #Received Higher Accuracy
    lstm_layer = keras.layers.RNN(keras.layers.LSTMCell(units), input_shape=(None, input_dim))
    model = keras.models.Sequential(
        [
            lstm_layer,
            keras.layers.BatchNormalization(),
            keras.layers.Dense(output_size),
        ]
    )
    model.summary()
    return model

# %% [markdown]
# # Load the MNIST dataset

# %%
mnist = keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
sample, sample_label = x_train[0], y_train[0]

# %% [markdown]
# # Train Model

# %%
model = build_model()

model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer="sgd",
    metrics=["accuracy"],
)


model.fit(
    x_train, y_train, validation_data=(x_test, y_test), batch_size=batch_size, epochs=1
)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn_1 (RNN)                  (None, 64)                23808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# =================================================================
# Total params: 24,714
# Trainable params: 24,586
# Non-trainable params: 128
# _________________________________________________________________
# 938/938 [==============================] - 20s 20ms/step - loss: 1.3097 - accuracy: 0.5813 - val_loss: 0.5584 - val_accuracy: 0.8169

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpugfeq2sp/assets

# %%
from google.colab import files
files.download('model.tflite')
